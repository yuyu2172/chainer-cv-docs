# %%
# %matplotlib inline
from chainercv.datasets.image_folder_dataset import ImageFolderDataset

# %%
dataset = ImageFolderDataset('/mnt/sdb/datasets/aaa/val/')

# %%
shapes = [out[0].shape for out in dataset]

# %%
min_size = [min(shape[1:]) for shape in shapes]

# %%
import seaborn
seaborn.distplot(min_size)

max(min_size)
# Out:
# 3646

# %%
min_size_arr = np.array(min_size)
print sum(min_size_arr > 422) / float(min_size_arr.size)
# Out:
# 0.19044
