# %%
import matplotlib.pyplot as plt
from chainer_uc.datasets.unite_the_people_dataset import UniteThePeopleDataset

# %%
dataset = UniteThePeopleDataset()

# %%
for i in range(20):
    img, joint, body, light_img, crop_info = dataset.get_raw_data(i)
    # there are 14 annotated joints.
    print(crop_info)
    print(img.shape)
    plt.close()
    plt.subplot(1, 2, 1)
    plt.imshow(img)
    plt.subplot(1, 2, 2)
    plt.imshow(light_img)
    plt.show()
# Out:
# 201 145 0 201 0 145
# (201, 145, 3)
# 178 90 0 178 0 90
# (178, 90, 3)
# 175 102 0 175 0 102
# (175, 102, 3)
# 196 154 0 196 0 154
# (196, 154, 3)
# 201 170 0 201 0 170
# (201, 170, 3)
# 172 92 0 172 0 92
# (172, 92, 3)
# 142 121 0 142 0 121
# (142, 121, 3)
# 170 74 0 170 0 74
# (170, 74, 3)
# 198 147 0 198 0 147
# (198, 147, 3)
# 188 93 0 188 0 93
# (188, 93, 3)
# 190 158 0 190 0 158
# (190, 158, 3)
# 180 93 0 180 0 93
# (180, 93, 3)
# 158 70 0 158 0 70
# (158, 70, 3)
# 158 78 0 158 0 78
# (158, 78, 3)
# 174 79 0 174 0 79
# (174, 79, 3)
# 144 146 0 144 0 146
# (144, 146, 3)
# 158 113 0 158 0 113
# (158, 113, 3)
# 181 92 0 181 0 92
# (181, 92, 3)
# 157 63 0 157 0 63
# (157, 63, 3)
# 178 84 0 178 0 84
# (178, 84, 3)
